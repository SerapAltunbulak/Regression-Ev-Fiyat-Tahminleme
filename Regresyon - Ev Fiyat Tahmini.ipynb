# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
abs(df.corr()['price']).sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# zipcode          0.053203
# condition        0.036362
# long             0.021626
# id               0.016762
# Name: price, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['day'] = df['date'].apply(lambda date: date.day)
df['month'] = df['date'].apply(lambda date: date.month)
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df['month_name'] = df['date'].dt.month_name()
df['weekday'] = df['date'].dt.day_name()

# %%
df['age'] = 2021 - df['yr_built']

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
sns.boxplot(df['bedrooms']);

# %%
sns.boxplot(df['bathrooms']);

# %%
sns.boxplot(df['floors']);

# %%
df = df[df['bedrooms'] < 7]
df = df[df['bathrooms'] < 5]

# %%
df['bathrooms'] = df['bathrooms'] ** 3
df['bedrooms'] = df['bedrooms'] ** 3

# %%
sns.boxplot(df['grade']);

# %%
df = df[df['grade'] > 4]
df = df[df['grade'] < 11]

# %%
sns.boxplot(df['waterfront']);

# %%
sns.boxplot(df['view']);

# %%
sns.boxplot(df['sqft_living']);

# %%
df = df.drop('waterfront', axis=1)
df = df[df['view'] < 2.5]
df = df[df['sqft_living'] < 4500]

# %%
sns.boxplot(df['sqft_living15']);

# %%
sns.boxplot(df['sqft_lot15']);

# %%
sns.boxplot(df['sqft_above']);

# %%
sns.boxplot(df['sqft_basement']);

# %%
df = df[df['sqft_living15'] < 4000]
df = df[df['sqft_lot15'] < 20000]
df = df[df['sqft_above'] < 4000]
df = df[df['sqft_basement'] < 1500]

# %%
sns.boxplot(df['condition']);

# %%
df = df[df['condition'] > 3]

# %%
sns.boxplot(df['age']);

# %%
df = df[df['age'] > 25]
df = df[df['age'] < 70]

# %%
sns.boxplot(df['floors']);

# %%
df = df[df['floors'] < 2.75]

# %%
df.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  3.772000e+03  3.772000e+03  3772.000000  3772.000000  3772.000000
# mean   4.518421e+09  4.486294e+05    47.130965     9.216082  1874.450954
# std    2.804028e+09  2.370203e+05    33.878491     7.790420   606.554336
# min    2.352019e+07  8.900000e+04     1.000000     0.421875   490.000000
# 25%    2.193338e+09  2.750000e+05    27.000000     3.375000  1410.000000
# 50%    3.885806e+09  3.900000e+05    27.000000     8.000000  1820.000000
# 75%    7.214813e+09  5.600000e+05    64.000000    15.625000  2250.000000
# max    9.842300e+09  2.300000e+06   216.000000    91.125000  4250.000000
#
#             sqft_lot       floors         view    condition        grade  ...  \
# count    3772.000000  3772.000000  3772.000000  3772.000000  3772.000000  ...
# mean    10296.318664     1.189024     0.093849     4.175504     7.366914  ...
# std     10095.024189     0.381981     0.401792     0.380448     0.792800  ...
# min      1675.000000     1.000000     0.000000     4.000000     5.000000  ...
# 25%      7500.000000     1.000000     0.000000     4.000000     7.000000  ...
# 50%      8968.000000     1.000000     0.000000     4.000000     7.000000  ...
# 75%     10857.250000     1.000000     0.000000     4.000000     8.000000  ...
# max    426450.000000     2.500000     2.000000     5.000000    10.000000  ...
#
#        month_name_May  month_name_November  month_name_October  \
# count     3772.000000          3772.000000         3772.000000
# mean         0.111612             0.061771            0.076352
# std          0.314930             0.240771            0.265596
# min          0.000000             0.000000            0.000000
# 25%          0.000000             0.000000            0.000000
# 50%          0.000000             0.000000            0.000000
# 75%          0.000000             0.000000            0.000000
# max          1.000000             1.000000            1.000000
#
#        month_name_September  weekday_Monday  weekday_Saturday  weekday_Sunday  \
# count           3772.000000     3772.000000       3772.000000     3772.000000
# mean               0.083775        0.182927          0.014581        0.010339
# std                0.277087        0.386658          0.119885        0.101169
# min                0.000000        0.000000          0.000000        0.000000
# 25%                0.000000        0.000000          0.000000        0.000000
# 50%                0.000000        0.000000          0.000000        0.000000
# 75%                0.000000        0.000000          0.000000        0.000000
# max                1.000000        1.000000          1.000000        1.000000
#
#        weekday_Thursday  weekday_Tuesday  weekday_Wednesday
# count       3772.000000      3772.000000        3772.000000
# mean           0.182662         0.228791           0.208378
# std            0.386440         0.420110           0.406202
# min            0.000000         0.000000           0.000000
# 25%            0.000000         0.000000           0.000000
# 50%            0.000000         0.000000           0.000000
# 75%            0.000000         0.000000           0.000000
# max            1.000000         1.000000           1.000000
#
# [8 rows x 40 columns]

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(), annot=True);

# %%
abs(df.corr()['price']).sort_values(ascending=False)
# Out:
# price                   1.000000
# sqft_living15           0.694631
# grade                   0.636985
# sqft_living             0.620486
# sqft_above              0.513765
# lat                     0.492253
# bathrooms               0.429557
# sqft_lot15              0.271122
# sqft_basement           0.256158
# bedrooms                0.254384
# floors                  0.245038
# view                    0.220140
# sqft_lot                0.096355
# zipcode                 0.086318
# condition               0.079173
# yr_renovated            0.069671
# month_name_June         0.034920
# day                     0.032288
# month                   0.032081
# weekday_Wednesday       0.030452
# long                    0.030217
# month_name_December     0.029364
# weekday_Monday          0.026715
# month_name_October      0.024923
# year                    0.023832
# month_name_February     0.023139
# id                      0.021642
# month_name_March        0.015426
# weekday_Sunday          0.015413
# weekday_Tuesday         0.014701
# month_name_September    0.013077
# month_name_July         0.012978
# weekday_Thursday        0.010703
# month_name_August       0.010381
# month_name_May          0.009564
# month_name_November     0.006035
# month_name_January      0.005715
# weekday_Saturday        0.005380
# age                     0.004810
# yr_built                0.004810
# Name: price, dtype: float64

# %%
data = df[['sqft_living', 'grade', 'sqft_living15', 'sqft_above', 'bathrooms', 'lat', 'bedrooms', 'floors', 'sqft_basement', 'sqft_lot15', 'view', 'price']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3772 entries, 3 to 21303
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   
# 10873         1580      7           1590        1580  15.625000  47.3768
# 15259         1840      7           1820        1390  11.390625  47.7328
# 2044          2720      9           2640        2720  27.000000  47.5833
# 3833          1310      8           2100        1310   3.375000  47.6644
# 6786          1720      7           1870        1720   1.000000  47.7736
# 5175          1530      7           1530        1040   5.359375  47.4483
#
#        bedrooms  floors  sqft_basement  sqft_lot15  view     price
# 12796        27     1.0              0        8996     0  317000.0
# 14329        64     1.0            550        8000     0  340000.0
# 16470        64     2.0              0        7432     0  305500.0
# 13720        27     1.0              0       10050     0  410000.0
# 4011         27     1.0            450        9375     0  314950.0
# 8959        125     1.0            910        9370     0  400000.0
# 10286        64     2.0            860       14300     0  401500.0
# 7795         27     1.0              0        9461     0  240000.0
# 13996         8     1.0              0        4200     0  160000.0
# 17271        27     1.0            780        6040     0  423000.0
# 12309       125     1.0            810        8964     0  270000.0
# 6230         27     1.0            600        7350     0  269500.0
# 7099          8     1.0              0        8206     0  237950.0
# 5306         27     1.0              0        8540     0  412500.0
# 10873        64     2.0              0        6633     0  291000.0
# 15259        64     1.0            450        7500     0  442500.0
# 2044         64     1.0              0       11740     0  940000.0
# 3833         27     1.0              0        9449     0  524000.0
# 6786         27     1.0              0        8640     0  399950.0
# 5175         27     1.0            490        8690     0  279950.0

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet 
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor


from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
def algo_test(data, y_name):
    
    L = LinearRegression()
    E = ElasticNet()
    R = Ridge()
    Lass = Lasso()
    ETR = ExtraTreeRegressor()
    GBR = GradientBoostingRegressor()
    RFR = RandomForestRegressor()
    
    algo_names = ['Linear', 'ElasticNet', 'Ridge', 'Lasso', 'ExtraTree', 'GradientBoosting', 'RandomForest']
    algos = [L, E, R, Lass, ETR, GBR, RFR]
    r_squared = []
    rmse = []
    mae = []
    
    X = data.drop(columns=[y_name], axis=1)
    y = data[y_name]
    
    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=.2,random_state=42)
    
    result = pd.DataFrame(columns= ['R_Squared', 'RMSE', 'MAE'], index = algo_names)
    
    for algo in algos:
        algo.fit(X_train, y_train)
        pred = algo.predict(X_test)
        
        r_squared.append(r2_score(y_test, pred))
        rmse.append(mean_squared_error(y_test, pred)**.5)
        mae.append(mean_absolute_error(y_test, pred))
    
    result.R_Squared = r_squared
    result.RMSE = rmse
    result.MAE = mae
    return result.sort_values('R_Squared', ascending=False)

# %%
algo_test(data, 'price')
# Out:
#                   R_Squared           RMSE            MAE
# RandomForest       0.839222   86204.105514   56615.595294
# GradientBoosting   0.836692   86879.616162   57819.772661
# Lasso              0.687411  120198.944861   89776.278961
# Linear             0.687410  120199.141205   89776.556373
# Ridge              0.687407  120199.798695   89742.912492
# ExtraTree          0.560371  142546.674545   88769.639073
# ElasticNet         0.542338  145440.944246  113312.739281
